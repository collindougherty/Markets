# %%
import requests
import json
import pandas as pd

# %%
API_KEY = '20sodZ8XOxJvfbreRnTFONeTUQF'

# %%
urls = {'https://api.glassnode.com/v1/metrics/market/price_usd_close',
        'https://api.glassnode.com/v1/metrics/distribution/exchange_net_position_change',
        'https://api.glassnode.com/v1/metrics/indicators/reserve_risk', 
        'https://api.glassnode.com/v1/metrics/indicators/puell_multiple',
       'https://api.glassnode.com/v1/metrics/indicators/rhodl_ratio',
       'https://api.glassnode.com/v1/metrics/market/mvrv_z_score',
       'https://api.glassnode.com/v1/metrics/indicators/sopr_adjusted',
       'https://api.glassnode.com/v1/metrics/indicators/net_unrealized_profit_loss',
       'https://api.glassnode.com/v1/metrics/mining/marketcap_thermocap_ratio'}

# %%
data = []
for url in urls:
    label = url.split('/')[-1]
    
    #make API request
    res = requests.get(url,params={'a': 'BTC', 'api_key': API_KEY})
    
    #convert to pandas dataframe
    df = pd.read_json(res.text, convert_dates=['t'])
    df.set_index('t', inplace = True)
    df.rename(columns={'v':label}, inplace= True)
    data.append(df)

# %%
# creating a dataframe from the list of results generated from the API
data_df = pd.concat(data, axis=1)
data_df
# Out:
#             net_unrealized_profit_loss  mvrv_z_score  price_usd_close  \
# t
# 2009-01-03                         NaN      0.000000              NaN
# 2009-01-04                         NaN           NaN              NaN
# 2009-01-05                         NaN           NaN              NaN
# 2009-01-06                         NaN           NaN              NaN
# 2009-01-07                         NaN           NaN              NaN
# ...                                ...           ...              ...
# 2021-12-01                    0.569798      2.671663     57182.676014
# 2021-12-02                    0.564203      2.606896     56448.448681
# 2021-12-03                    0.542734      2.374127     53765.796483
# 2021-12-04                    0.500216      1.998843     48962.920993
# 2021-12-05                         NaN           NaN     48870.596544
#
#             puell_multiple  marketcap_thermocap_ratio  \
# t
# 2009-01-03             NaN                        NaN
# 2009-01-04             NaN                        NaN
# 2009-01-05             NaN                        NaN
# 2009-01-06             NaN                        NaN
# 2009-01-07             NaN                        NaN
# ...                    ...                        ...
# 2021-12-01        1.200194                   0.000002
# 2021-12-02        1.337253                   0.000002
# 2021-12-03        1.424949                   0.000002
# 2021-12-04        1.146894                   0.000001
# 2021-12-05             NaN                        NaN
#
#             exchange_net_position_change   rhodl_ratio  sopr_adjusted  \
# t
# 2009-01-03                           NaN           NaN            NaN
# 2009-01-04                           NaN           NaN            NaN
# 2009-01-05                           NaN           NaN            NaN
# 2009-01-06                           NaN           NaN            NaN
# 2009-01-07                           NaN           NaN            NaN
# ...                                  ...           ...            ...
# 2021-12-01                 -24587.158110  10447.598656       1.015373
# 2021-12-02                 -34682.056808   9866.568057       0.999716
# 2021-12-03                 -26947.166530   9412.539603       0.993727
# 2021-12-04                 -18613.020117   9576.710725       0.959018
# 2021-12-05                           NaN           NaN            NaN
#
#             reserve_risk
# t
# 2009-01-03           NaN
# 2009-01-04           NaN
# 2009-01-05           NaN
# 2009-01-06           NaN
# 2009-01-07           NaN
# ...                  ...
# 2021-12-01      0.003950
# 2021-12-02      0.003895
# 2021-12-03      0.003831
# 2021-12-04      0.003356
# 2021-12-05           NaN
#
# [4720 rows x 9 columns]

# %%
data_df.to_csv('C:/Users/colli/Documents/R/Bitcoin/apidata.csv')
