# %% [markdown]
# # Options Data

# %%
import yfinance as yf
import pandas as pd

# %%
aapl = yf.Ticker("AAPL")
current_price = aapl.info['regularMarketPrice']
dates = aapl.options
options = aapl.option_chain().calls
for i in dates:
    it_options = aapl.option_chain(date = i)
    call_options = it_options.calls
    options = options.append(call_options)
#options.calls

# %%
options
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0   AAPL220729C00070000 2022-07-22 19:07:50+00:00    70.0      83.71  83.65
# 1   AAPL220729C00080000 2022-07-20 19:51:29+00:00    80.0      73.25  73.50
# 2   AAPL220729C00085000 2022-07-22 16:05:53+00:00    85.0      69.40  68.40
# 3   AAPL220729C00090000 2022-07-22 17:10:48+00:00    90.0      64.30  63.80
# 4   AAPL220729C00095000 2022-07-18 18:50:43+00:00    95.0      52.55  58.25
# ..                  ...                       ...     ...        ...    ...
# 43  AAPL240621C00280000 2022-07-22 17:51:35+00:00   280.0       2.99   2.71
# 44  AAPL240621C00290000 2022-07-20 19:04:01+00:00   290.0       2.55   2.16
# 45  AAPL240621C00300000 2022-07-22 19:58:49+00:00   300.0       2.16   1.95
# 46  AAPL240621C00310000 2022-07-21 17:30:54+00:00   310.0       1.89   1.22
# 47  AAPL240621C00320000 2022-07-22 19:30:08+00:00   320.0       1.75   1.50
#
# ...

# %%
tradable_options = options[options.loc[:,'volume']>100]

# %%
tradable_options['midpoint'] = .5*(tradable_options['bid']+tradable_options['ask'])
tradable_options['breakeven'] = tradable_options['midpoint'] + tradable_options['strike']
tradable_options
# Out:
# <ipython-input-55-85d3b6abff8d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tradable_options['midpoint'] = .5*(tradable_options.loc[:,'bid']+tradable_options.loc[:,'ask'])
# <ipython-input-55-85d3b6abff8d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tradable_options['breakeven'] = tradable_options.loc[:,'midpoint'] + tradable_options.loc[:,'strike']
#          contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# ...

# %%
tradable_options['be_move_needed'] = tradable_options['breakeven'] - current_price
tradable_options['be_percent_move_needed'] = 100*tradable_options['move_needed']/current_price
tradable_options['exercise_value'] = current_price - tradable_options['strike']
tradable_options['5pct_move'] =(current_price*1.05)-tradable_options['strike']
tradable_options
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 6   AAPL220729C00105000 2022-07-22 19:37:02+00:00   105.0      49.13  48.75
# 7   AAPL220729C00110000 2022-07-22 19:36:27+00:00   110.0      44.21  43.50
# 18  AAPL220729C00128000 2022-07-22 19:08:31+00:00   128.0      25.75  25.95
# 20  AAPL220729C00130000 2022-07-22 19:58:41+00:00   130.0      24.05  24.10
# 25  AAPL220729C00135000 2022-07-22 19:52:02+00:00   135.0      19.27  19.25
# ..                  ...                       ...     ...        ...    ...
# 41  AAPL240119C00260000 2022-07-22 18:54:32+00:00   260.0       2.35   2.27
# 45  AAPL240119C00300000 2022-07-22 19:49:40+00:00   300.0       1.10   0.95
# 2   AAPL240621C00060000 2022-07-21 19:15:07+00:00    60.0      98.25  96.85
# 18  AAPL240621C00140000 2022-07-22 19:31:24+00:00   140.0      38.00  37.50
# 22  AAPL240621C00160000 2022-07-22 19:54:00+00:00   160.0      27.90  27.40
#
# ...

# %%
import numpy as np
n = np.linspace(0,2, 101)
price_moves = current_price*n
exercise_vals = price_moves - 105
exercise_vals
# Out:
# array([-105.    , -101.9182,  -98.8364,  -95.7546,  -92.6728,  -89.591 ,
#         -86.5092,  -83.4274,  -80.3456,  -77.2638,  -74.182 ,  -71.1002,
#         -68.0184,  -64.9366,  -61.8548,  -58.773 ,  -55.6912,  -52.6094,
#         -49.5276,  -46.4458,  -43.364 ,  -40.2822,  -37.2004,  -34.1186,
#         -31.0368,  -27.955 ,  -24.8732,  -21.7914,  -18.7096,  -15.6278,
#         -12.546 ,   -9.4642,   -6.3824,   -3.3006,   -0.2188,    2.863 ,
#           5.9448,    9.0266,   12.1084,   15.1902,   18.272 ,   21.3538,
#          24.4356,   27.5174,   30.5992,   33.681 ,   36.7628,   39.8446,
#          42.9264,   46.0082,   49.09  ,   52.1718,   55.2536,   58.3354,
#          61.4172,   64.499 ,   67.5808,   70.6626,   73.7444,   76.8262,
#          79.908 ,   82.9898,   86.0716,   89.1534,   92.2352,   95.317 ,
#          98.3988,  101.4806,  104.5624,  107.6442,  110.726 ,  113.8078,
#         116.8896,  119.9714,  123.0532,  126.135 ,  129.2168,  132.2986,
# ...

# %%
current_price
# Out:
# 154.09
